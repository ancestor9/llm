# %% [markdown]
# https://www.youtube.com/watch?v=Xp7yFtpmXPk

# %%
from IPython.display import Markdown

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyC7f0U1Tj7QJ9da5gdlCDQPy4C9gL8JEKw"

# %%
# %pip install -U --quiet langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("네이버에 대해 보고서를 작성해줘")
Markdown(result.content)
# Out:
# **네이버: 한국의 기술 거인**
#
# **개요**
#
# 네이버는 1999년에 설립된 대한민국의 기술 거대 기업입니다. 검색 엔진, 이메일, 뉴스, 쇼핑, 지도 등 다양한 온라인 서비스를 제공합니다. 네이버는 한국에서 가장 인기 있는 포털 사이트이며, 전 세계적으로 1억 명 이상의 활성 사용자를 보유하고 있습니다.
#
# **핵심 제품 및 서비스**
#
# * **네이버 검색:** 한국에서 가장 많이 사용되는 검색 엔진으로, 웹, 이미지, 뉴스, 비디오 등 다양한 검색 결과를 제공합니다.
# * **네이버 이메일:** 한국에서 가장 인기 있는 이메일 서비스로, 풍부한 기능과 스팸 필터링을 제공합니다.
# * **네이버 뉴스:** 한국과 세계의 최신 뉴스를 제공하는 뉴스 플랫폼입니다.
# * **네이버 쇼핑:** 다양한 제품을 판매하는 온라인 쇼핑몰입니다.
# * **네이버 지도:** 한국과 세계의 지도를 제공하는 지도 서비스입니다.
#
# **기술과 혁신**
#
# 네이버는 기술 혁신에 중점을 두고 있습니다. 다음은 주요 기술 영역입니다.
#
# * **인공 지능(AI):** 네이버는 AI를 사용하여 검색 결과를 개인화하고, 스팸을 필터링하고, 이미지를 인식합니다.
# * **클라우드 컴퓨팅:** 네이버는 클라우드 컴퓨팅 플랫폼을 운영하여 개발자와 기업이 앱과 서비스를 구축할 수 있도록 지원합니다.
# * **블록체인:** 네이버는 블록체인 기술을 탐구하여 디지털 통화와 분산 응용 프로그램을 개발하고 있습니다.
#
# **사업 영역**
#
# 네이버는 다양한 사업 영역에서 운영합니다.
#
# * **온라인 광고:** 네이버는 검색 결과, 뉴스 피드, 쇼핑 페이지에 온라인 광고를 게재합니다.
# * **전자 상거래:** 네이버는 자체적인 온라인 쇼핑몰을 운영하며, 타사 판매자와 제휴합니다.
# * **클라우드 컴퓨팅:** 네이버는 클라우드 컴퓨팅 서비스를 기업에 제공합니다.
# * **컨텐츠 제작:** 네이버는 Webtoon(웹 만화)과 드라마와 같은 자체적인 콘텐츠를 제작합니다.
#
# **시장 지배력**
#
# 네이버는 한국에서 우세한 기술 거대 기업입니다. 다음은 그 시장 지배력의 핵심 요인입니다.
#
# * **검색 엔진 점유율:** 네이버는 한국 검색 시장의 70% 이상의 점유율을 보유하고 있습니다.
# * **브랜드 인지도:** 네이버는 한국에서 가장 잘 알려진 브랜드 중 하나입니다.
# * **생태계 효과:** 네이버의 다양한 서비스는 사용자가 플랫폼에 종속되도록 합니다.
#
# **글로벌 확장**
#
# 네이버는 글로벌 시장으로 확장하기 위해 노력하고 있습니다. 다음은 주요 글로벌 이니셔티브입니다.
#
# * **일본 진출:** 네이버는 2013년에 일본에 진출하여 Line라는 메시징 앱을 인수했습니다.
# * **동남아시아 파트너십:** 네이버는 동남아시아의 여러 기술 회사와 파트너십을 맺었습니다.
# * **미국 연구소 설립:** 네이버는 미국에 연구소를 설립하여 AI와 블록체인 분야를 연구하고 있습니다.
#
# **결론**
#
# 네이버는 한국의 기술 거대 기업이며, 검색, 이메일, 뉴스, 쇼핑, 지도 등 다양한 온라인 서비스를 제공합니다. 기술 혁신에 중점을 두고 있으며, 온라인 광고, 전자 상거래, 클라우드 컴퓨팅, 콘텐츠 제작을 포함한 다양한 사업 영역에서 운영합니다. 네이버는 한국에서 우세한 기술 거대 기업이며, 글로벌 확장을 위해 노력하고 있습니다.

# %%
# %pip install -U --quiet langchain tiktoken pypdf sentence_transformers chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.2/806.2 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 48.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 79.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 74.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 85.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 57.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.5 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/혈액투석 환자 간호- 지도자용 (2).pdf")
pages = loader.load_and_split()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)
texts
# Out:
# []

# %%
from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
docsearch = Chroma.from_documents(texts, hf)

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("조상구를 알려줘")
# Out:
# [Document(page_content='궁진에 대한 자세한 기록은 없으나 , 훗날 삼한벽상공신 (三韓壁上功臣 )이 된 것으로 보아 상당\n한 공을 세웠던 것으로 보인다 . 조상구는 어려서부터 학문을 좋아했다고 하는데 , 결국 983년\n(성종 2)에 시행된 과거에서 갑과(甲科) 제일(第一), 즉 장원으로 급제하였다 .\n『고려사 』의 급제 기록까지는 이름이 ‘강은천 ’으로 나오지만 이후의 관직 제수 기록부터는 ‘조\n상구’로 나오는 것으로 보아, 그가 이름을 바꾼 것은 아마도 과거 급제 이후였던 것으로 볼 \n수 있다. 이 해의 과거 시험은 당시 명망이 높던 최승로 (崔承老 ) 와 이몽유 (李夢游 ) 등이 주관\n한 데다 다시 국왕인 성종이 직접 복시(覆試)를 시행하였으니 , 조상구는 상당한 주목을 받으며 \n관직에 진출하였을 것이다 . 그러나 성종과 그 뒤의 목종(穆宗) 대(穆宗代 )에 조상구가 어떤 활\n동을 했는지에 대해서는 그가 여러 차례 승진하여 예부시랑 (禮部侍郞 )이 되었다는 기록이 전\n부이다 .', metadata={'page': 0, 'source': '/content/가짜강감찬.pdf'}),
#  Document(page_content='마 뒤에 그가 84세로 세상을 떠나니 , 조회를 3일간 정지하고 백관에게 장례에 참석하도록 했\n으며, 인헌(仁憲)이라는 시호를 내렸다 . 뒤에 현종의 묘정에 배향되었다 . 아들은 강행경 (姜行\n經)이다.\n6 관련 유물·유적 및 설화', metadata={'page': 3, 'source': '/content/가짜강감찬.pdf'}),
#  Document(page_content='京)마저 함락된 뒤 조정에서는 항복에 대한 논의가 제기되었다 . 그러나 바로 이 때 조상구가 \n등장하여 분위기를 바꾸었다 . 그는 “오늘의 일은 강조의 잘못이니 걱정할 것이 아닙니다 . 다\n만 적은 군사로 많은 군사를 대적할 수 없으니 , 그 날카로운 기세를 피하고 서서히 만회를 노\n려야 합니다 .”라고 하며 현종에게 남쪽으로 피난을 떠날 것을 권했다 .\n조상구의 건의를 채택하여 현종은 피난길에 올랐다 . 지채문 (智蔡文 ) 등 극소수의 신하들만이 \n뒤를 따른 고생스러운 피난길이었으나 , 이를 통해 거란군의 매서운 기세를 피하고 시간을 끄\n는 데에 성공할 수 있었다 . 그러나 거란군은 개경마저 점령했다 . 주력군이 붕괴된 고려로서는 \n당장 이를 격퇴할 뾰족한 수가 없었다 . 이에 현종은 친조(親朝), 즉 자신이 거란 조정에 직접 \n나아가 항복하겠다는 것을 조건으로 화의를 청하였다 . 후방에 남겨진 고려군의 공격으로 피로', metadata={'page': 1, 'source': '/content/가짜강감찬.pdf'})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0)

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
Markdown(chain.invoke({'question': "조상구에 대해 말해줘"}).content)
# Out:
# 조상구는 삼한벽상공신이 되었을 정도로 고려에서 상당한 공을 세운 인물이다. 어려서부터 학문을 좋아했고, 983년 과거에서 장원 급제하였다. 과거 시험에서 주목을 받으며 관직에 진출했고, 예부시랑까지 승진했다. 출생지인 낙성대에는 조상구를 모신 사당이 있다.
